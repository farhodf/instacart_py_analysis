# %%
# Importing Libraries 
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/farhodfurkatov/Desktop/CF Data Immersion Achievment 4/Instacart Basket Analysis/02 Data'

# %%
cust = pd.read_csv(os.path.join(path, 'Original Data', 'customers.csv'))

# %%
#create df with 2 columns to merge with our df_2 dataframe 
cust_state = cust[['user_id', 'STATE']]

# %%
cust_state.head()
# Out:
#    user_id       STATE    Regions   Regions2 Result Regions11
# 0    26711    Missouri  Northeast        NaN    NaN   Midwest
# 1    33890  New Mexico  Northeast        NaN    NaN      West
# 2    65803       Idaho  Northeast  Northeast    NaN      West
# 3   125935        Iowa  Northeast  Northeast    NaN   Midwest
# 4   130797    Maryland  Northeast        NaN    NaN     South

# %%
cust.shape
# Out:
# (206209, 10)

# %%
ords = pd.read_csv(os.path.join(path, 'Original Data', 'orders.csv'))

# %%
ords.shape
# Out:
# (3421083, 7)

# %%
cust.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
dups_cust = cust[cust.duplicated()]

# %%
dups_cust
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surnam, Gender, STATE, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# creating the regions column
result11 = []

for value in cust_state['STATE']:
    
    if value == 'Maine' or value == 'New Hampshire' or value == 'Vermont' or value == 'Massachusetts' or value == 'Rhode Island' or value == 'Connecticut' or value == 'New York' or value == 'New Jersey' or value == 'Pennsylvania':
        result11.append('Northeast')
    elif value == 'Wisconsin' or value == 'Michigan' or value == 'Illinois' or value == 'Indiana' or value == 'Ohio' or value == 'North Dakota' or value == 'South Dakota' or value == 'Nebraska' or value == 'Kansas' or value == 'Minnesota' or value == 'Iowa' or value == 'Missouri' :
        result11.append('Midwest')
    elif value == 'Delaware' or value == 'Maryland' or value == 'District of Columbia' or value == 'Virginia' or value == 'West Virginia' or value == 'North Carolina' or value == 'South Carolina' or value == 'Georgia' or value == 'Florida' or value == 'Kentucky' or value == 'Tennessee' or value == 'Mississippi' or value == 'Alabama' or value == 'Oklahoma' or value == 'Texas' or value == 'Arkansas' or value == 'Louisiana':
        result11.append('South')
    else:
        result11.append('West')

# %%
result11
# Out:
# ['Midwest',
#  'West',
#  'West',
#  'Midwest',
#  'South',
#  'South',
#  'West',
#  'South',
#  'South',
#  'South',
#  'West',
#  'Midwest',
#  'South',
#  'West',
#  'West',
#  'Midwest',
#  'Midwest',
#  'Midwest',
#  'West',
#  'Northeast',
#  'Midwest',
#  'South',
#  'Northeast',
#  'South',
#  'West',
#  'West',
#  'South',
#  'Midwest',
#  'West',
#  'South',
#  'South',
#  'West',
#  'West',
#  'Northeast',
#  'West',
#  'Midwest',
#  'Northeast',
#  'West',
#  'South',
#  'Midwest',
#  'West',
#  'Midwest',
#  'Northeast',
#  'Northeast',
#  'West',
#  'Northeast',
#  'West',
#  'Midwest',
#  'South',
#  'South',
#  'Midwest',
#  'West',
#  'West',
#  'West',
#  'South',
#  'West',
#  'Midwest',
#  'South',
#  'Midwest',
#  'West',
#  'South',
#  'West',
#  'West',
#  'West',
#  'Midwest',
#  'West',
#  'West',
#  'West',
#  'Northeast',
#  'West',
#  'South',
#  'Northeast',
#  'Northeast',
#  'South',
#  'Northeast',
#  'Northeast',
#  'West',
#  'West',
# ...

# %%
cust_state['Regions11'] = result11
# Out:
# /Users/farhodfurkatov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cust_state.head(50)
# Out:
#     user_id           STATE    Regions   Regions2 Result  Regions11
# 0     26711        Missouri  Northeast        NaN    NaN    Midwest
# 1     33890      New Mexico  Northeast        NaN    NaN       West
# 2     65803           Idaho  Northeast  Northeast    NaN       West
# 3    125935            Iowa  Northeast  Northeast    NaN    Midwest
# 4    130797        Maryland  Northeast        NaN    NaN      South
# 5    133128        Kentucky  Northeast        NaN    NaN      South
# 6    152052         Montana  Northeast        NaN    NaN       West
# 7    168851  South Carolina  Northeast        NaN    NaN      South
# 8     69965           Texas  Northeast        NaN    NaN      South
# 9     82820        Virginia  Northeast        NaN    NaN      South
# 10    26441          Nevada  Northeast        NaN    NaN       West
# 11    33835        Nebraska  Northeast        NaN    NaN    Midwest
# 12    75032         Georgia  Northeast        NaN    NaN      South
# ...

# %%
cust_state['Regions11'].value_counts(dropna = False)
# Out:
# South        68737
# West         52565
# Midwest      48519
# Northeast    36388
# Name: Regions11, dtype: int64

# %%
opm = pd.read_csv(os.path.join(path, 'Prepared Data', 'orders_products_merged.csv'))

# %%
opm_dups = opm[opm.duplicated()]

# %%
opm_dups
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 24828734   2564286      236            32                  1
# 24828736   1759951      236            33                  4
# 24828738   2508582     1021            30                  2
# 24828740     98185     1264             1                  0
# 24828742   1306167     1264             2                  4
# ...            ...      ...           ...                ...
# 32433506   1528096   137438            16                  1
# 32433508   1450541   137438            18                  1
# 32433510   1118413   155030             6                  3
# 32433512   2744037   159487             1                  2
# 32433514   1564616   180527             2                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 24828734                 23                     2.0       35306
# 24828736                  0                     3.0       35306
# ...

# %%
opmc = opm.drop_duplicates()

# %%
opmc.shape
# Out:
# (32433030, 14)

# %%
opmc.to_csv(os.path.join(path, 'Prepared Data', 'orders_products_merged.csv'), index = False)

# %%
opmc.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))
