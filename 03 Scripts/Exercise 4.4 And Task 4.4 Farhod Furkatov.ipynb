# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Creating path to orders and prods folder
path = r'/Users/farhodfurkatov/Desktop/CF Data Immersion Achievment 4/Instacart Basket Analysis/02 Data/Original Data'

# %%
path
# Out:
# '/Users/farhodfurkatov/Desktop/CF Data Immersion Achievment 4/Instacart Basket Analysis/02 Data/Original Data'

# %%
#creating Orders df
df_ords = pd.read_csv(os.path.join(path, 'orders.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#creating Products df
df_prods = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
#  30.0    369323
#  7.0     320608
#  6.0     240013
#  4.0     221696
#  3.0     217005
#  5.0     214503
# NaN      206209
#  2.0     193206
#  8.0     181717
#  1.0     145247
#  9.0     118188
#  14.0    100230
#  10.0     95186
#  13.0     83214
#  11.0     80970
#  12.0     76146
#  0.0      67755
#  15.0     66579
#  16.0     46941
#  21.0     45470
#  17.0     39245
#  20.0     38527
#  18.0     35881
#  19.0     34384
#  22.0     32012
#  28.0     26777
#  23.0     23885
#  27.0     22013
#  24.0     20712
#  25.0     19234
#  29.0     19191
#  26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
df_dep = pd.read_csv(os.path.join(path, 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9   ...               12      13         14  \
# 0  beverages  pets  dry goods pasta   ...     meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transponding df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9   ...               12      13         14  \
# 0  beverages  pets  dry goods pasta   ...     meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
df_dep_t.head
# Out:
# <bound method NDFrame.head of                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing>

# %%
#take the firstrow of df_dep_t for the header 
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header #set the header row as the df header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#convert the df to dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '2': {'department': 'other'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19')) #get 19 from df dict
# Out:
# {'department': 'snacks'}

# %%
#to look only at snacks department
df_snacks = df_prods[df_prods['department_id']== 19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# option2 
df_snacks_2 = df_prods.loc[df_prods['department_id']==19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# option 3
df_snack_3 = df_prods.loc[df_prods['department_id'].isin ([19])]

# %%
path2 = r'/Users/farhodfurkatov/Desktop/CF Data Immersion Achievment 4/Instacart Basket Analysis/02 Data/Prepared Data'

# %%
df_ords.to_csv(os.path.join(path2, 'orders_wrangled.csv'))

# %% [markdown]
# # Task 4.4

# %% [markdown]
# ## Step 2

# %%
df_ords.describe()
# Out:
#             user_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.029782e+05  1.715486e+01        2.776219e+00       1.345202e+01
# std    5.953372e+04  1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.139400e+04  5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.026890e+05  1.100000e+01        3.000000e+00       1.300000e+01
# 75%    1.543850e+05  2.300000e+01        5.000000e+00       1.600000e+01
# max    2.062090e+05  1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
# check data type of user_id
df_ords['user_id'].dtype
# Out:
# dtype('int64')

# %%
# change to string
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Step 3

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# all column names look good for me, for this task I will change orders_day_of_week to order_day_of_week, (without 's' on orders)
df_ords.rename(columns = {'orders_day_of_week' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## Step 4

# %%
#to find busiest hour we will look at order_hour_of_day and most frequent number (10:00 busiest hour)
df_ords.order_hour_of_day.mode()
# Out:
# 0    10
# dtype: int64

# %% [markdown]
# ## Step 5

# %%
df_prods.department_id.head()
# Out:
# 0    19
# 1    13
# 2     7
# 3     1
# 4    13
# Name: department_id, dtype: int64

# %%
# they are number of departments and we can look it up department_id in our df_dep_t_new dataframe
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#department_id 4 is Produce department

# %% [markdown]
# ## Step 6

# %%
# We will look only at Breakfasr department sales which is Dep 4
#create breakfast df
df_breakfast = df_prods[df_prods['department_id']== 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# 215           216                  Gluten Free Oatmeal, Variety Pack
# 221           222                          Honey Nut Oatmeal Squares
# 237           238                       Alpha-Bits Multigrain Cereal
# 251           252                                 Waffles, Red Berry
# 287           288  Original Sprouted Grains Protein & Fiber Hot O...
# 339           340                         Eco-Pac Kamut Puffs Cereal
# 364           365                                    Cheerios Cereal
# 437           438  Special K Vanilla Cappuccino Protein Breakfast...
# ...

# %%
df_breakfast.describe()
# Out:
#          product_id     aisle_id  department_id       prices
# count   1116.000000  1116.000000         1116.0  1116.000000
# mean   25464.490143   101.517921           14.0     7.848208
# std    14271.353221    33.890362            0.0     3.971678
# min       28.000000    48.000000           14.0     1.000000
# 25%    12754.250000    57.000000           14.0     4.400000
# 50%    26268.000000   121.000000           14.0     7.700000
# 75%    38035.250000   130.000000           14.0    11.300000
# max    49663.000000   130.000000           14.0    14.900000

# %% [markdown]
# ## Step 7

# %%
# we will create df_dinner_party to abserve info on customers who might be throwing dinner parties
# Combine info on departments alcohol, deli, beverages and mest/seafood

# %%
# first look at id's of those specific deoartments
# we will look at dictionary table we created earlier 
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '2': {'department': 'other'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'}}

# %%
# alcohol = Dep 5, deli = Dep 20, beverages = Dep 7, meat seafood = Dep 12
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
df_dinner_party
# Out:
#        product_id                                       product_name  \
# 2               3               Robust Golden Unsweetened Oolong Tea
# 6               7                     Pure Coconut Water With Orange
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# 10             11                                  Peach Mango Juice
# 16             17                                  Rendered Duck Fat
# 19             20     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 22             23                             Organic Turkey Burgers
# 34             35     Italian Herb Porcini Mushrooms Chicken Sausage
# 38             39           Daily Tangerine Citrus Flavored Beverage
# 39             40  Beef Hot Links Beef Smoked Sausage With Chile ...
# 43             44                        Sparkling Raspberry Seltzer
# 48             49      Vegetarian Grain Meat Sausages Italian - 4 CT
# 51             52                                Mirabelle Brut Rose
# ...

# %% [markdown]
# ## Step 8

# %%
# Rows and Columns of new df
df_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# ## Step 9

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# order_day_of_week           int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# first I couldnt create customer 1 tabele as user_id was string, I changed to interger and created new table

# %%
df_ords['user_id'] = df_ords['user_id'].astype('int64')

# %%
# creating table for customer with user_id 1
df_cust1 = df_ords.loc[df_ords['user_id'] == 1]

# %%
df_cust1
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
# 5   3367565        1             6                  2                  7
# 6    550135        1             7                  1                  9
# 7   3108588        1             8                  1                 14
# 8   2295261        1             9                  1                 16
# 9   2550362        1            10                  4                  8
# 10  1187899        1            11                  4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# ## Step 10

# %%
df_cust1.describe()
# Out:
#        user_id  order_number  order_day_of_week  order_hour_of_day  \
# count     11.0     11.000000          11.000000          11.000000
# mean       1.0      6.000000           2.636364          10.090909
# std        0.0      3.316625           1.286291           3.477198
# min        1.0      1.000000           1.000000           7.000000
# 25%        1.0      3.500000           1.500000           7.500000
# 50%        1.0      6.000000           3.000000           8.000000
# 75%        1.0      8.500000           4.000000          13.000000
# max        1.0     11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# this user shopped 11 times
# most popular days to order Tuesday and Friday
# prefers to place the orders in the mornings
# Orders on average every 19 days

# %% [markdown]
# ## Step 11

# %%
# line 41 df_ords.to_csv(os.path.join(path2, 'orders_wrangled.csv'))

# %% [markdown]
# ## Step 12

# %%
df_dep_t_new.to_csv(os.path.join(path2, 'departments_wrangled.csv'))

# %%
df_ords.head()
# Out:
#   order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                  2                  8
# 1  2398795        1             2                  3                  7
# 2   473747        1             3                  3                 12
# 3  2254736        1             4                  4                  7
# 4   431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.to_csv(os.path.join(path2, 'orders_wrangled.csv'), index = False)
