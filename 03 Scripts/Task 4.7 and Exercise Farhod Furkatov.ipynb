# %% [markdown]
# # Exercise follow 4.7

# %%
# Importing libraries 
import pandas as pd
import pickle
import numpy as np
import os

# %%
# Creating path to Data Folder 
path = r'/Users/farhodfurkatov/Desktop/CF Data Immersion Achievment 4/Instacart Basket Analysis/02 Data'

# %%
# importing the file 
df_ords_prods_merged = pd.read_csv(os.path.join(path, 'Prepared Data', 'orders_products_merged.csv'), index_col = False)

# %%
df = df_ords_prods_merged[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# define the function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <=15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# Apply the function 
df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# /Users/farhodfurkatov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'
# Out:
# /Users/farhodfurkatov/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid Range product'
# Out:
# /Users/farhodfurkatov/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'
# Out:
# /Users/farhodfurkatov/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid Range product    756450
# Low range product    243550
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: order_day_of_week, dtype: int64

# %%
# For loop for busiest days
result = []

for value in df_ords_prods_merged['order_day_of_week']:
    if value ==0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regular busy')

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Busiest day',
# ...

# %%
# adding busiest day column to our dataframe
df_ords_prods_merged['busiest_day'] = result

# %%
# looking up the column
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regular busy    22437387
# Busiest day      6209632
# Least busy       3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task 4.7

# %% [markdown]
# ## Step 2 and 3

# %%
# For loop for 2 busiest days and 2 slowest days
result_2 = []

for value in df_ords_prods_merged['order_day_of_week']:
    if value ==0 or value == 1:
        result_2.append('Busiest days')
    elif value == 3 or value == 4:
        result_2.append('Least busy days')
    else:
        result_2.append('Regular busy days')

# %%
#check
result_2
# Out:
# ['Regular busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regular busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Busiest days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy days',
#  'Regular busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest days',
#  'Regular busy days',
#  'Regular busy days',
#  'Regular busy days',
#  'Least busy days',
#  'Regular busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regular busy days',
#  'Regular busy days',
# ...

# %%
# adding busiest days column to our dataframe
df_ords_prods_merged['busiest_days'] = result_2

# %%
# looking up the column
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regular busy days    12927461
# Busiest days         11875462
# Least busy days       7631289
# Name: busiest_days, dtype: int64

# %%
# Busiest days and least busiest days values increased where regular busy days value decreased

# %%
#looking up our dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#dropping busiest_day column 
ords_prods_merge = df_ords_prods_merged.drop(columns=['busiest_day'])

# %%
#checking new df
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ## Step 4

# %%
# to check busiest hours for orders
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
# for this I will divide the day in to 3 equeal parts

result_hour = []

for value in ords_prods_merge['order_hour_of_day']:
    if value >= 9 and value <= 16:
        result_hour.append('Most Orders')
    elif value >= 0 and value <=6 or value == 23:
        result_hour.append('Fewest Orders')
    else:
        result_hour.append('Average orders')

# %%
result_hour
# Out:
# ['Average orders',
#  'Average orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
# ...

# %%
# adding the busiest_period_of_day column to our df
ords_prods_merge['busiest_period_of_day'] = result_hour

# %% [markdown]
# ## Step 5

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most Orders       21137262
# Average orders    10006752
# Fewest Orders      1290198
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge.pkl'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-86-05875f742cfe> in <module>()
# ----> 1 ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge.pkl'))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol)
#    1562         from pandas.io.pickle import to_pickle
#    1563         return to_pickle(self, path, compression=compression,
# -> 1564                          protocol=protocol)
#    1565
#    1566     def to_clipboard(self, excel=None, sep=None, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/pickle.py in to_pickle(obj, path, compression, protocol)
#      43         protocol = pkl.HIGHEST_PROTOCOL
#      44     try:
# ---> 45         pkl.dump(obj, f, protocol=protocol)
#      46     finally:
#      47         for _f in fh:
#
# ...

# %%
ords_prods_merge.to_csv(os.path.join(path, 'Prepared Data', 'ords_prods_merged.csv'), index = False)
